# %% [markdown]
# <a href="https://colab.research.google.com/github/DanaeMartinez01/Metodos-Numericos-/blob/main/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

def funcion1(x):
    return x**3 + 4*x**2 - 10.0

# Ingreso datos de entrada para los diferentes métodos a trabajar
a = 1
b = 2

# guarda valores iniciales
a0 = a
b0 = b

#guarda valores iniciales del error y del número de iteraciones
tol = 0.000001
nmax = 100
error = 100
niter = 0

# MÉTODO DE BISECCIÓN
print("=== MÉTODO DE BISECCIÓN ===")
# evaluo primer valor medio
m = a + (b - a) / 2

# Evaluación de la función en los puntos a, b y m
fa = funcion1(a)
fb = funcion1(b)
fm = funcion1(m)

print("# iter\t\t a \t\t f(a) \t\t b \t\t f(b) \t\t m \t\t f(m) \t\t error")
print("{0} \t\t {1:6.4f} \t {2:6.4f} \t {3:6.4f} \t {4:6.4f} \t {5:6.4f} \t {6:6.4f} \t {7:6.4f}".format(niter, a0, fa, b0, fb, m, fm, error))

# Ciclo iterativo para el método de Bisección
while error > tol and niter < nmax:
    m = a + (b - a) / 2
    if np.sign(fa) == np.sign(fm):
        a = m
        fa = funcion1(a)
    else:
        b = m
        fb = funcion1(b)

    m = a + (b - a)/2
    fm = funcion1(m)
    error = abs(b - a)
    niter += 1
    print("{0} \t\t {1:6.6f} \t {2:6.6f} \t {3:6.6f} \t {4:6.6f} \t {5:6.6f} \t {6:6.6f} \t {7:6.6f}".format(niter, a, fa, b, fb, m, fm, error))

print("La raíz de la función dada en el intervalo [{0:6.4f},{1:6.4f}] es {2:6.7f}".format(a0,b0,m))


# MÉTODO DE ITERACIÓN DE PUNTO FIJO
# Para usar el método de punto fijo necesitamos reescribir la ecuación f(x) = 0 en la forma x = g(x).
# g(x) = sqrt((10 - x^3) / 4)
def g(x):
    return sqrt((10 - x**3) / 4)

# Parámetros del método de punto fijo
p0 = 1.5  # Valor inicial
error_punto_fijo = 100
niter_punto_fijo = 0

print("\n=== MÉTODO DE ITERACIÓN DE PUNTO FIJO ===")
print("# iter\t\t p_n \t\t g(p_n) \t\t error")

# Ciclo iterativo para el método de Iteración de Punto Fijo
while error_punto_fijo > tol and niter_punto_fijo < nmax:
    p1 = g(p0)
    error_punto_fijo = abs(p1 - p0)

    # Imprimir la iteración actual y el error
    print("{0} \t\t {1:6.6f} \t {2:6.6f} \t {3:6.6f}".format(niter_punto_fijo, p0, p1, error_punto_fijo))

    p0 = p1  # Actualizar el valor de p0
    niter_punto_fijo += 1

if error_punto_fijo <= tol:
    print(f"La solución aproximada por punto fijo es: {p1} con un error de {error_punto_fijo}")
else:
    print("No se alcanzó la tolerancia en el número máximo de iteraciones.")
# Out:
# === MÉTODO DE BISECCIÓN ===
# # iter		 a 		 f(a) 		 b 		 f(b) 		 m 		 f(m) 		 error
# 0 		 1.0000 	 -5.0000 	 2.0000 	 14.0000 	 1.5000 	 2.3750 	 100.0000
# 1 		 1.000000 	 -5.000000 	 1.500000 	 2.375000 	 1.250000 	 -1.796875 	 0.500000
# 2 		 1.250000 	 -1.796875 	 1.500000 	 2.375000 	 1.375000 	 0.162109 	 0.250000
# 3 		 1.250000 	 -1.796875 	 1.375000 	 0.162109 	 1.312500 	 -0.848389 	 0.125000
# 4 		 1.312500 	 -0.848389 	 1.375000 	 0.162109 	 1.343750 	 -0.350983 	 0.062500
# 5 		 1.343750 	 -0.350983 	 1.375000 	 0.162109 	 1.359375 	 -0.096409 	 0.031250
# 6 		 1.359375 	 -0.096409 	 1.375000 	 0.162109 	 1.367188 	 0.032356 	 0.015625
# 7 		 1.359375 	 -0.096409 	 1.367188 	 0.032356 	 1.363281 	 -0.032150 	 0.007812
# 8 		 1.363281 	 -0.032150 	 1.367188 	 0.032356 	 1.365234 	 0.000072 	 0.003906
# 9 		 1.363281 	 -0.032150 	 1.365234 	 0.000072 	 1.364258 	 -0.016047 	 0.001953
# 10 		 1.364258 	 -0.016047 	 1.365234 	 0.000072 	 1.364746 	 -0.007989 	 0.000977
# ...
