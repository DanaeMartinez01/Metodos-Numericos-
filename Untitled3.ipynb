# %% [markdown]
# <a href="https://colab.research.google.com/github/DanaeMartinez01/Metodos-Numericos-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sympy

# %%
import sympy as spy

x=spy.Symbol('x')
g=spy.exp(x/2)*spy.sin(x/3)
#calcular la primera derivada
f_uno=spy.diff(g, x)
print(g)
print(f_uno)

# %%
#calcular la segunda derivada
f_dos=spy.diff(f_uno, x)
print(f_dos)

# %%
#calcular la tercera derivada
f_tres=spy.diff(f_dos, x)
print(f_tres)

# %%
#calcular la cuarta derivada
f_cuatro=spy.diff(f_tres, x)
print(f_cuatro)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return np.exp(x/2)*np.sin(x/3)
#crear un rango de valores para x
x=np.linspace(-10, 10, 400)

def g(x):
  return np.(1/3)*x
def h(x):
  return np.1/3*x+np.(1/6)*x**2
def i(x)

#graficar la funcion
plt.figure(figsize=(8,6))
#plt.plot(x, y, label=)
plt.title('grafica del polinomio de Maclaurin')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)

plt.plot(x,y)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
